# %% [markdown]
# There are three type of recommendation system
# -  **colaborative** filtering
# -  **content** based filtering
# -  **hybrid** (both collaborative and content based filtering

# %% [markdown]
# **what is colaborative filtering:**
#
# *colaborative filtering is based on user interaction
# suppose two users like a single movie so in colaborative filtering it will be decised that these 2 person has simmiler type of taste . suppose if 2 of them like batman movie then other it will be recommended it too*
# it only focus on the user interaction
#
# **what is content based filtering:** <br>
#
# content based system check for the content properties and the user info and find a relation.if a user inly watch comedy movie then the commedy move will be recommended to the users
#
#
# **what is Hybrid recommendation system :**<br>
# it is the both content based and colaborative filtering

# %% [markdown]
# **Evaluation technique**
#
# prediction error(most improtant properties):
# - mesure prediction error(reduce in any cost)
# - good recommendation system should have low prediction error
#
# Diverse:
# - Recommendation system should be diverse
# - if the recommendation system always recommended fixed couple of item
# then it will become popular and it will be recommended again and again
# .Means it will make the popular item moe popular and other potential system dont get shown at all.Recommended should have high diversity
#
# Coverage:
# - greater system shoul have high coverage.it will happen only when diversity is good.
# - content coverage and user coverage
#
# serendipity:
#  what is serendipity: make unexpected and fourtunate discovery
#  - good recommendation system would surprise the user with unexpected and new items that user would never find out by themselves.
#
#  - its job to surprise the user

# %% [markdown]
# # Colaborative filtering
# ---------------------------
# - colaborative filtering is used for personalized reommendation
# - Recomendation of an active users is calculated based on other users
# - in a short other users collaborate to make a recommendation of the users
# - it used the past interaction data (remember the interaction not the content , collaborative filtering is not content baseed)
# now when we talk about interaction what do we mean?
# - there are two types of interaction like
# - 1) expicit interaction (for example rating of the movie)
# - 2) implicit interaction (views, click, buys)
# But how to project this data
# - we can make a matrix like in the x axis is the users
# - and in the y axis is the movie and the usrs can give the rating based on the item. usres can give any number from 1-5 (depends ont the rating system)
# and if they dont interact with the movie then we give 0

# %% [markdown]
# Assumption of the Collaborative filtering
#
# -----------------------------------------
# - togather we can understand better
# - Similler preference in the past means similler preference in the future
# - preference remain same and consisteant over time

# %% [markdown]
# # how to quantify the similarity
# -------------------------------
# If we want to project a similarity into a mathmatical model then we need a function. That function will take 2 item as a parameter and then give us a score between 1 and 0 . based on the similarity .
# 1 means identical, 0  means no similarity
#
# - how you mathmatically find the users are similler?
# - suppose there are m numbers of movie
# - and an user X is giving rating to all of the movie
# so
#
# X(i) = [x1+x2+x3+......+xm]
# X(i) is the user
# and x1,x2,x3 to xm are the rating of the movies given by the user X(i)
#
# supose this is a vector eqation
# X(1) = [x1+x2+x3+......+xm]
# <br>
# Now 2 users are similler of the give same amount of rating to the same movies
#
# second users movie recommendation is
# X(2) = [x1+x2+x3+......+xm]
#
# **we need tp find the similarity between 2 vectors. then we find the similarity between 2 users**
#
# - so how to find the 2 vectors similarity?
#
# we can find the similarity between w vector by canculating Euclidean distance
# if the distace is less then similarity is high if the distance is big then similarity is low.
# <br>
# suppose there are 3 movies and 2 users
# X(a) = [4,3,2]
# X(b) = [5,2,1]
#
# F(a,b) =  np.sqrt((4-5)** 2+(3-2) **2+(2-1) **2)
#
# ths is the similarity based wth the euclidian distance
#
# there is another similarity function called cosine similarity
#
#
# why cosine similarity is necessary ?
# - suppose rating is 10 based and here is two users rating
# X(a) = [1,2,4,3,5,6,7,8,9,10]
# X(b) = [5,2,1,2,3,5,6,7,6,0]
#
# cosine similarity if the product of the element of the individual vector and then sum it up.the intuation is if the corresponding of two element is same then their prodict will be higher other wise will be lower if dissimilar. it works better if one of the corresponding element is 0. then the product is lower.suppose 1 user rates the movie 10 and another does not see the movie so 0. so the product will be 0 because if dont dont see the mvie then there is no similarity score
#
#
# C(a,b) = 4 * 5 + 3 * 2 + 2 * 1
# Its the sumation of the product of the element
# it is usefull when any propeties is 0
#
#
# **another similarity function is  calld pearson coefficient**

# %% [markdown]
# ![Screenshot from 2023-08-18 08-14-37.png](data:image/png;base64,...)

# %% [markdown]
# Euclidian distance measures![Screenshot from 2023-08-18 08-17-26.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2023-08-18 08-26-06.png](data:image/png;base64,...)

# %% [markdown]
# #  Collaborative filtering workflow (Remember collaborative filtering depends on interaction matrix)
# ---------------------

# %% [markdown]
# ![Screenshot from 2023-08-18 08-51-57.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2023-08-18 08-53-19.png](data:image/png;base64,...)

# %% [markdown]
# # Disadvantage
# ![Screenshot from 2023-08-18 09-07-04.png](data:image/png;base64,...)
